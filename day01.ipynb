# %% [markdown]
# <a href="https://colab.research.google.com/github/009vinaysharma/AWS-ML-Arya/blob/main/day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Vinay Sharma")
# Out:
# Vinay Sharma

# %%
# variable
a = 'Hello'
print(a)
print(id(a))

b = 'Hello'
print(b)
print(id(b))
# Out:
# Hello
# 139938237913808
# Hello
# 139938237913808

# %%
# arith opr(+,--*-/-%-//-> floor division)
num1 = 10
num2 = 20
print(num1 + num2)
print(num1 - num2)
print(num1 * num2)
print(num1 / num2)
print(num1 % num2)
print(num1 // num2)
# Out:
# 30
# -10
# 200
# 0.5
# 10
# 0

# %%
# logical opr ( and , or , not)

num1 = 'hello'
num2 = []
print(not num1)

print(not num2)

num3 = 10
num4 = 20
print(num3 and num4)

num3 = []
num4 = 20
print(num3 and num4)

num3 = 10
num4 = []
print(num3 and num4)

num3 = []
num4 = []
print(num3 and num4)
# Out:
# False
# True
# 20
# []
# []
# []

# %%
num1 = {"name": "vinay"}
num2 = [20]
print(not num1 and not num2)
# Out:
# False

# %%
num1 = {"name": "vinay"}
num2 = [20]
print( num1 and num2)
# Out:
# [20]

# %%
a = "Vinay Sharma"
print(a)
# Out:
# Vinay Sharma

# %%
#variable
num = 10
print(num)
print(id(num))

num1 = 10
print(num1)
print(id(num1))
print(type(num))
# Out:
# 10
# 11645640
# 10
# 11645640
# <class 'int'>

# %%
num = 10
print(num)
print(id(num))

num = 20
print(num)
print(id(num))
# Out:
# 10
# 11645640
# 20
# 11645960

# %%
str = "Vinay"
print(str)
print(id(str))
print(type(str))

str = "Sharma"
print(str)
print(id(str))
# Out:
# Vinay
# 139938238087840
# <class 'str'>
# Sharma
# 139938238088512

# %%
is_student = True

print(is_student)
print(id(is_student))
print(type(is_student))

is_student = False

print(is_student)
print(id(is_student))
# Out:
# True
# 10549600
# <class 'bool'>
# False
# 10549568
